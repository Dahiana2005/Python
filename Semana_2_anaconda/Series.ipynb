# %%
import pandas as pd

# %%
manzanas = pd.Series([5,8,12,4,6,3])
print(manzanas)
# Out:
# 0     5
# 1     8
# 2    12
# 3     4
# 4     6
# 5     3
# dtype: int64

# %%
prueba_colores = pd.Series(['rojo','amarillo','morado','verde'])
print(prueba_colores)
prueba_colores[0:3]
# Out:
# 0        rojo
# 1    amarillo
# 2      morado
# 3       verde
# dtype: object
# 0        rojo
# 1    amarillo
# 2      morado
# dtype: object

# %%
notas = pd.Series({'Matematicas':4.3,'Español':3.2,'Sociales':2.1,'Naturales':3.7})
print(notas)
# Out:
# Matematicas    4.3
# Español        3.2
# Sociales       2.1
# Naturales      3.7
# dtype: float64

# %%
numeros = pd.Series([23,56,41,78,98,34,63])
numeros.size
# Out:
# 7

# %%
numeros.index
# Out:
# RangeIndex(start=0, stop=7, step=1)

# %%
numeros.dtype
# Out:
# dtype('int64')

# %%
numeros = pd.Series([23,56,41,78,98,34,63])
numeros * 6
# Out:
# 0    138
# 1    336
# 2    246
# 3    468
# 4    588
# 5    204
# 6    378
# dtype: int64
