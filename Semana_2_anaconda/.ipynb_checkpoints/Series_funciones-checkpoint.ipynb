# %%
import pandas as pd

# %%
numeros = pd.Series([4,6,3,8,2,31,21,67,46])
numeros.sum()
numeros.max()
numeros.min()
numeros.std()
numeros.describe()
# Out:
# count     9.000000
# mean     20.888889
# std      22.937112
# min       2.000000
# 25%       4.000000
# 50%       8.000000
# 75%      31.000000
# max      67.000000
# dtype: float64
