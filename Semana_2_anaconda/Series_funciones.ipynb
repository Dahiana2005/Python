# %%
import pandas as pd

# %%
numeros = pd.Series([4,6,3,8,2,31,21,67,46])
numeros.sum()
numeros.max()
numeros.min()
numeros.std()
numeros.describe()
# Out:
# count     9.000000
# mean     20.888889
# std      22.937112
# min       2.000000
# 25%       4.000000
# 50%       8.000000
# 75%      31.000000
# max      67.000000
# dtype: float64

# %%
estatura_animales = pd.Series({'Jirafa':235,'Gato':143,'Perro':180,'Tucan':120,'Mariposa':43,'Oso':543})
print(estatura_animales[estatura_animales>254])
print(estatura_animales[estatura_animales<157])
print(estatura_animales.sort_values())
# Out:
# Oso    543
# dtype: int64
# Gato        143
# Tucan       120
# Mariposa     43
# dtype: int64
# Mariposa     43
# Tucan       120
# Gato        143
# Perro       180
# Jirafa      235
# Oso         543
# dtype: int64

# %%
import numpy as np
a1 = np.array([1, 2, 3])
print(a1)
# Out:
# [1 2 3]
